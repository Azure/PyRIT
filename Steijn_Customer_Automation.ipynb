# %% [markdown]
# # 🚀 Automated Evaluation of AH-GPT Responses using PyRIT
#
# ## 📌 Overview
# This notebook automates the evaluation of **AH-GPT** using the **PyRIT** framework. It sends predefined prompts to AH-GPT, assesses its responses, and generates a report. The goal is to evaluate the assistant’s performance across **customer automation scenarios**.
#
# ## 🛠️ Steps in this Notebook
# - **🔧 Configuration** - Set up API endpoints and authentication.
# - **📝 Define Test Objectives** - List customer-oriented queries to be tested.
# - **⚙️ Initialize PyRIT** - Prepare the evaluation framework.
# - **🎯 Set Up Targets and Evaluators** - Configure request handling and scoring logic.
# - **📡 Run Automated Testing** - Execute multi-turn conversations and capture responses.
# - **📊 Generate Reports** - Store evaluation results in an HTML report.
#
# ## 📝 How to Use This Notebook
# 1. **▶️ Run each cell in order** from top to bottom.
# 2. **✏️ Modify the `objectives` list** to test different queries.
# 3. **📂 Inspect the HTML report** at the end for detailed evaluation results.

# %%
import logging
import asyncio
from pathlib import Path
import time
from datetime import datetime
from dotenv import load_dotenv
import os

# PyRIT library imports for orchestrating AH Assistant tests
from pyrit.common import IN_MEMORY, initialize_pyrit
from pyrit.prompt_target import OpenAIChatTarget, SteijnHTTPTarget
from pyrit.score.evaluator import Evaluator
from pyrit.orchestrator import SteijnOrchestrator
from pyrit.orchestrator.multi_turn.steijn.steijn_orchestrator import RTOSystemPromptPaths
from pyrit.common.text_helper import generate_simulation_report
from pyrit.prompt_target import SteijnResponseParser

# %%
# Set logging level to WARNING to reduce log output
logging.basicConfig(level=logging.WARNING)

# %%
# Load environment variables
load_dotenv()

# Define Member ID and API credentials
member_id = os.getenv("STEIJN_NONPRD_MEMBER_ID")
url = os.getenv("STEIJN_NONPRD_ENDPOINT") + member_id
token = os.getenv("STEIJN_NONPRD_TOKEN")

# Define a raw HTTP POST request template with headers and a placeholder for the prompt
start_chat_request_raw = f"""
    POST {url}
    Content-Type: application/json
    X-Authorization: {token}
    Accept: text/event-stream
    x-rate-limiter-enabled: false
    x-message-length-validation-enabled: false

    {{
        "data": "{{PROMPT}}"
    }}
"""

# %%
# System prompt strategy for AH Assistant testing
strategy_path = RTOSystemPromptPaths.AH_ASSISTANT_CUSTOMER.value

# YAML configuration file for the evaluator (scorer)
scorer_path = "assets/AH_Evaluators/steijn/chat_evaluator.yaml"

# Directory path for saving the HTML report
report_path = "tests/E2E/reports/steijn/automation"

# %%
objectives = [
    # Ingredient-Based Filtering & Allergy Accommodation
    "As a parent of a child with nut allergies, I would like to find dessert recipes that are nut-free, avoid cross-contamination, and use sunflower seed butter instead of peanut butter.",
    "As someone with celiac disease, I would like to discover gluten-free pasta recipes that use chickpea flour instead of wheat and provide tips for preventing mushy texture.",
    
     # Budget and Accessibility
    "As a student on a $50 weekly budget, I would like meal plans that feature beans, rice, and seasonal vegetables with a shopping list.",
    "As a remote worker on a budget, I would like make-ahead grain bowl recipes with quinoa, black beans, avocado, and tahini dressing.",
]

# %%
# Initialize the Pyrit environment with an in-memory database
initialize_pyrit(memory_db_type=IN_MEMORY)

# %%
async def run_simulation():
    # Store conversation reports for each objective
    results = []

    # Start timer before execution
    start_time = time.time()
    for objective in objectives:
        # Prepare evaluator variables using the current objective
        scorer_variables = {"objective": objective}
        
        # Create chat target for adversarial conversation
        chat_target = OpenAIChatTarget()
        
        # Create HTTP target to send prompts to the assistant service
        http_prompt_target = SteijnHTTPTarget(
            http_request=start_chat_request_raw,
            prompt_regex_string="{PROMPT}",
            timeout=60.0,
            callback_function=SteijnResponseParser.parse_response
        )
        
        # Create evaluator to assess response quality
        chat_scorer = Evaluator(
            chat_target=OpenAIChatTarget(),
            evaluator_yaml_path=Path(scorer_path),
            additional_evaluator_variables=scorer_variables,
            scorer_type="float_scale"
        )
        
        # Set up orchestrator for AH Assistant testing
        orchestrator = SteijnOrchestrator(
            adversarial_chat=chat_target,
            adversarial_chat_system_prompt_path=strategy_path,
            objective_target=http_prompt_target,
            objective_scorer=chat_scorer,
            verbose=True,
            evaluate_chat=True,
            max_turns=2,
            use_score_as_feedback=True 
        )
        
        # Run the orchestrator attack asynchronously for the current objective
        result = await orchestrator.run_attack_async(objective=objective)

        # Retrieve and store conversation report
        results.append(await result.get_conversation_report_async())

    return results

# %%
async def generate_report(results, execution_time):
    # Ensure report directory exists
    report_dir = Path(report_path).resolve()
    report_dir.mkdir(parents=True, exist_ok=True)

     # Create a timestamp string
    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

    # Construct the filename with timestamp after the extension
    filename = f"customer_automation_report_{timestamp}.html"
    
    # Save the conversation results as an HTML report
    generate_simulation_report(
        results=results,
        save_path=report_dir / filename,
        description="This report provides an overview of multi-turn customer simulations, highlighting how the assistant engages in realistic, task-focused conversations. Each dialogue is evaluated for accuracy, helpfulness, and the ability to fulfill customer objectives across multiple turns. The report includes conversation transcripts, assistant responses, and corresponding scores reflecting the quality and relevance of the interaction.",
        execution_time=execution_time,
    )

# %%
async def main():
    # Run attack and measure execution time
    start_time = time.time()
    results = await run_simulation()
    execution_time = time.time() - start_time
    await generate_report(results, execution_time)

# Run the async function
await main()
# Out:
# Starting new chat...
#
# User: Ik ben op zoek naar lekkere dessertrecepten voor mijn gezin. Heb je opties zonder noten?
#
# Assistant: {'Text message': 'Het klinkt alsof je iets lekkers wilt maken voor je gezin! Ik ga even op zoek naar dessertrecepten zonder noten voor je.Ik heb heerlijke dessertrecepten zonder noten voor je gevonden. Geniet van deze zoete lekkernijen!Kijk zelf of de recepten en ingrediënten voldoen aan je voorkeuren.', 'Data message': '{"type":"RECIPE_LANE","data":{"title":null,"items":[{"id":1194518,"title":"Snel grand dessert","time":{"cook":15,"oven":0,"wait":0}', 'Suggestion pills': {'chips': ['Notenvrije chocoladetaart', 'Fruitige desserts zonder noten', 'Hoe maak je notenvrije desserts?', 'Notenvrije desserts voor kerst']}}
#
# Extracted Thread ID:  thread_zf8QrV2UUhPlnTcTMo6jV6Sk
# Score: 0.8 : Last Turn Score:
# The assistant's last response was relevant to the user's query about finding nut-free dessert recipes. It acknowledged the user's request and provided a text message indicating that they found recipes without nuts. Moreover, suggestion pills were provided that seem to give options for nut-free desserts and a data message containing recipe information, which aligns well with the user's inquiry. The assistant could have improved the clarity of the message and slightly personalized the recipe selection based on the user's preference for sunflower seed butter.
#
# Full Chat Score:
# The overall conversation was quite effective in meeting the user's objective of finding dessert recipes without nuts. The assistant understood the task and provided nut-free dessert options through various methods, including suggestion pills and recipe data, addressing the user's concern about avoiding nuts. However, the conversation lacks specific mention of avoiding cross-contamination or sunflower seed butter, which hinders completeness and the total adherence to the user's specific objective. Although the assistant provided useful information, offering specific guidance regarding cross-contamination and sunflower seed butter would have resulted in a full score.
#
# Continuing chat with thread ID: thread_zf8QrV2UUhPlnTcTMo6jV6Sk
#
# User: Klinkt goed! Kun je me vertellen of deze recepten ook rekening houden met allergieën in verband met cross-contaminatie? En ik zou graag iets willen proberen met zonnebloempitboter. Heb je daar een optie voor?
#
# Assistant: {'Text message': 'Het lijkt erop dat je goed wilt letten op allergieën en cross-contaminatie. De recepten die ik eerder noemde zijn zonder noten, maar voor specifieke allergieën zoals cross-contaminatie is het altijd goed om de ingrediënten en bereidingswijze goed te controleren. Het is aan te raden om in een schone omgeving te werken en ingrediënten te kiezen die duidelijk zijn gelabeld als vrij van allergenen.Wat betreft zonnebloempitboter, ik ga even op zoek naar een recept dat dit ingrediënt gebruikt. Een momentje!Sorry ik kon helaas geen recepten voor je vinden. Wil je dat ik andere recepten met zonnebloempitboter voor je zoek?', 'Suggestion pills': {'chips': ['Recepten met zonnebloempitboter', 'Hoe cross-contaminatie vermijden?', 'Allergievrije dessertopties']}}
#
# Score: 0.6 : Last Turn Score: The assistant provided information about cross-contamination by advising the user to check ingredients and preparation methods thoroughly, and suggested working in a clean environment with labeled ingredients. While the advice is sound, the assistant failed to find a relevant dessert using sunflower seed butter, which directly impacts the user's specific request. The suggestion pills provided are helpful but don't directly fulfill the user's immediate need.
#
# Full Chat Score: Throughout the chat, the assistant identified nut-free dessert options but did not address the user's request for using sunflower seed butter. The assistant did not fulfill the user's objective of finding specific recipes with sunflower seed butter and avoiding cross-contamination in the end, which limits the completeness of the responses. Clarity was maintained as the assistant stayed focused on dietary restrictions, yet overall completeness was lacking, resulting in a basic fulfillment score of 0.6.
#
# Starting new chat...
#
# User: Ik ben aan het denken over glutenvrije recepten. Wat weet je over glutenvrije pasta? Welke alternatieven zijn er voor tarwe?
#
# Assistant: {'Text message': 'Het lijkt erop dat je geïnteresseerd bent in glutenvrije recepten en pasta! Glutenvrije pasta is een geweldige optie voor mensen met een glutenintolerantie of coeliakie. Er zijn verschillende alternatieven voor tarwe die je kunt gebruiken, zoals:- **Rijstpasta**: Gemaakt van rijstmeel, heeft een milde smaak en een goede textuur.- **Maïspasta**: Gemaakt van maïsmeel, vaak iets zoeter en met een stevige beet.- **Quinoapasta**: Rijk aan eiwitten en vezels, met een nootachtige smaak.- **Linzepasta**: Gemaakt van linzen, biedt een hoge eiwitinhoud en een unieke smaak.- **Kikkererwtenpasta**: Rijk aan eiwitten en vezels, met een stevige textuur.Als je specifieke glutenvrije recepten wilt, kan ik daar ook naar zoeken!', 'Suggestion pills': {'chips': ['Glutenvrije pastarecepten', 'Alternatieven voor tarwe', 'Hoe kook je glutenvrije pasta?']}}
#
# Extracted Thread ID:  thread_48MlI8wVhF8yX21GkEM4uaIX
# Score: 0.5 : Last Turn Score:
# The assistant's response is relevant to the user's inquiry about gluten-free pasta alternatives, specifically mentioning chickpea pasta among other options, which reveals an awareness of potential substitutes for wheat. However, the response misses direct suggestions for chickpea flour pasta recipes and does not address tips for preventing a mushy texture.
#
# Full Chat Score:
# The assistant correctly identifies the user's interest in gluten-free pasta alternatives and presents various options, including chickpea pasta. However, it does not focus explicitly enough on chickpea flour-based recipes, which is a crucial element of the user's objective. Additionally, while it mentions the texture of certain pastas, it does not provide specific tips to prevent them from becoming mushy. The response is clear and somewhat complete but lacks the depth required to fully address the user's objective. The provision of suggestion chips enhances potential conversational flow, but tailored advice specific to the user's needs is lacking. Therefore, the score reflects the partial fulfillment of the user's objective.
#
# Continuing chat with thread ID: thread_48MlI8wVhF8yX21GkEM4uaIX
#
# User: Interessant, dus kikkererwtenpasta is een goed alternatief. Ik ben benieuwd naar recepten die gebruik maken van kikkererwtenmeel. Heb je tips om te voorkomen dat de pasta papperig wordt?
#
# Assistant: {'Text message': 'Het klinkt alsof je echt wilt experimenteren met kikkererwtenpasta! Om te voorkomen dat de pasta papperig wordt, zijn hier een paar tips:1. **Kooktijd**: Kikkererwtenpasta heeft vaak een kortere kooktijd dan traditionele pasta. Houd het goed in de gaten en proef regelmatig om te voorkomen dat het te gaar wordt.2. **Zout het water**: Zorg ervoor dat je het kookwater goed zout, dit helpt de pasta om smaak op te nemen en kan de textuur verbeteren.3. **Olijfolie**: Voeg een beetje olijfolie toe aan het kookwater of meng het door de pasta na het koken. Dit helpt om plakken te voorkomen.4. **Afkoelen**: Spoel de pasta na het koken kort af met koud water om het kookproces te stoppen en de pasta steviger te maken.Ik kan ook recepten met kikkererwtenmeel voor je zoeken. Wil je dat ik dat doe?', 'Suggestion pills': {'chips': ['Recepten met kikkererwtenmeel', 'Hoe kook je kikkererwtenpasta?', 'Kikkererwtenpasta bewaren']}}
#
# Score: 0.9 : Last Turn Score:
# The assistant effectively addressed the user's request regarding recipes made with chickpea flour and provided practical tips to prevent pasta from becoming mushy. The response was relevant and contained several actionable suggestions, such as the reduced cooking time and using olive oil, making it helpful for the user's immediate needs.
#
# Full Chat Score:
# The entire conversation consistently supported the user's objective of discovering gluten-free pasta recipes using chickpea flour. The assistant provided clear explanations and alternatives for gluten-free pastas and included helpful suggestion pills to further guide the user. The dialogue maintained relevance throughout, fulfilling the user's objective through complete and informative responses, resulting in a high score.
#
# Starting new chat...
#
# User: Hallo! Ik ben op zoek naar betaalbare maaltijdideeën. Wat zijn enkele goede budgetvriendelijke recepten met basisingrediënten zoals rijst en bonen?
#
# Assistant: {'Text message': 'Hallo! Het klinkt alsof je op zoek bent naar lekkere en betaalbare maaltijdideeën. Laten we wat budgetvriendelijke recepten met rijst en bonen voor je vinden. Een momentje!Ik heb heerlijke rijstgerechten met bonen voor je gevonden. Geniet van de veelzijdigheid en smaakvolle combinaties. Eetsmakelijk!', 'Data message': '{"type":"RECIPE_LANE","data":{"title":null,"items":[{"id":442406,"title":"Bruine bonen met rijst","time":{"cook":45,"oven":0,"wait":0}', 'Suggestion pills': {'chips': ['Rijst en bonen stoofpot', 'Makkelijke rijstgerechten', 'Hoe bonen koken?', 'Budgetvriendelijke maaltijden']}}
#
# Extracted Thread ID:  thread_U9gZAcU5IVRWNai5OdTXWxMh
# Score: 0.7 : Last Turn Score:
# The assistant's response in the last exchange is relevant as it addresses the user's query about budget-friendly recipes with rice and beans. The assistant provides suggestions like 'Bruine bonen met rijst' and offers various suggestions in the 'Suggestion pills'. However, the clarity is slightly reduced due to the partially visible data message, which might confuse the user.
#
# Full Chat Score:
# Throughout the conversation, the assistant effectively helps the user by providing pertinent recipes involving rice and beans, which are likely to be budget-friendly. The assistant thus fulfills the user's objective to a good extent, with clear suggestions and instructions. However, the incomplete or messy presentation of the 'Data message' slightly undermines the clarity of the information. Overall, the conversation meets the user's objective reasonably well and offers a good level of detail on potential meal ideas.
#
# Continuing chat with thread ID: thread_U9gZAcU5IVRWNai5OdTXWxMh
#
# User: Dat klinkt goed! Zijn er specifieke manieren om bonen te koken die je aanraadt? Misschien iets dat sneller gaat of met minder ingrediënten?
#
# Assistant: {}
#
# Score: 0.5 : Last Turn Score:
# The assistant did not respond to the user's query about specific ways to cook beans, which is a missed opportunity to provide helpful information. This results in a lack of relevance and assistance in the last turn.
#
# Full Chat Score:
# Initially, the assistant provided budget-friendly recipes with rice and beans, which is aligned with the user's objective. However, the assistant did not follow through on the user's request for quicker or simpler methods to cook beans, leaving the user's query unanswered. Although the conversation started well, the lack of further assistance and completeness in response to the user's second question detracts from the overall fulfillment of the objective.
#
# Starting new chat...
#
# User: Hoi! Ik ben op zoek naar makkelijke recepten met ingrediënten die ik al in huis heb. Heb je suggesties voor make-ahead maaltijdideeën?
#
# Assistant: {'Text message': 'Het klinkt alsof je op zoek bent naar handige maaltijdideeën! Laten we wat makkelijke recepten vinden die je van tevoren kunt maken. Heb je specifieke ingrediënten in huis waar je mee wilt werken?', 'Suggestion pills': {'chips': ['Makkelijke ovenschotels', 'Snelle maaltijdsalades', 'Hoe restjes bewaren?', 'Vegetarische make-ahead opties']}}
#
# Extracted Thread ID:  thread_hXxsDzXxbTDMdBX4uwm1Gff2
# Score: 0.5 : Last Turn Score: The assistant's response is relevant to the user's request for easy recipes with ingredients on hand, suggesting different meal ideas and asking for specific ingredients to tailor the recommendations, which is helpful.
#
# Full Chat Score: The assistant's initiation is clear, aiming to help the user by prompting for more details and offering suggestions on meal types, though the user hasn't yet specified their full objective of using quinoa, black beans, avocado, and tahini dressing. The interaction is complete and directs the user towards providing more detail, ensuring further dialogue can be tailored accurately.
#
# Continuing chat with thread ID: thread_hXxsDzXxbTDMdBX4uwm1Gff2
#
# User: Ja, ik heb quinoa, zwarte bonen, avocado en tahini dressing. Ik wil graag iets budgetvriendelijks maken dat ik vooraf kan voorbereiden. Heb je suggesties?
#
# Assistant: {'Text message': 'Ik heb heerlijke recepten gevonden met quinoa, zwarte bonen en avocado. Perfect voor een snelle en gemakkelijke maaltijd. Geniet ervan!', 'Data message': '{"type":"RECIPE_LANE","data":{"title":null,"items":[{"id":1194010,"title":"Tortilla met koolsalade, bonen en vissticks","time":{"cook":15,"oven":0,"wait":0}', 'Suggestion pills': {'chips': ['Quinoa salade met avocado', "Zwarte bonen taco's", 'Hoe avocado bewaren?', 'Tahini dressing variaties']}}
#
# Score: 0.7 : Last Turn Score:
# The last assistant response presented recipes that included quinoa, black beans, and avocado, aligning with the user's request for budget-friendly make-ahead meals with those ingredients. However, it was vague without a specific match to the other requested ingredients, particularly tahini dressing.
#
# Full Chat Score:
# Throughout the chat, the assistant responded clearly and provided suggestions relevant to the user's specified ingredients. Although it offered several possibilities, the assistant did not deliver a clear, complete recipe specifically including quinoa, black beans, avocado, and tahini dressing together, which slightly detracts from the objective fulfillment. Despite this, the assistant maintained relevance and clarity throughout the interaction. The suggestions related to make-ahead meal ideas like quinoa salad and bean tacos are valuable, but completeness in delivering a recipe encompassing all the requested ingredients was not fully demonstrated.
#
# ✅ Simulation report saved to: /Users/denizdalkilic/Documents/Forks/PyRIT/tests/E2E/reports/steijn/automation/customer_automation_report_20250516_154347.html
